# %%
# 28.04.2020
import os
from asreviewcontrib.visualization import Plot

# %%
# function to create custom inclusion plot
def inclusion_plot(plot, output=None, **kwargs):
    all_files = all(plot.is_file.values())
    inc_plot = plot.new("inclusion", **kwargs)
    inc_plot.set_grid()
    inc_plot.set_xlim(0, 40)
    inc_plot.set_ylim(0, 101)
    for key in list(plot.analyses):
        if all_files or not plot.is_file[key]:
            inc_plot.add_WSS(key, 95, add_text = False)
            inc_plot.add_RRF(key, 10, add_text = False)
    inc_plot.add_random(add_text = False)
    inc_plot.set_legend()
    if output is None:
        inc_plot.show()
    else:
        inc_plot.show()
        inc_plot.save(output)
        inc_plot.close()

# %%
# function to create custom inclusion plot, with no legend. 
def inclusion_plot_nolegend(plot, output=None, **kwargs):
    all_files = all(plot.is_file.values())
    inc_plot = plot.new("inclusion", **kwargs)
    inc_plot.set_grid()
    inc_plot.set_xlim(0, 40)
    inc_plot.set_ylim(0, 101)
    for key in list(plot.analyses):
        if all_files or not plot.is_file[key]:
            inc_plot.add_WSS(key, 95, add_text = False)
            inc_plot.add_RRF(key, 10, add_text = False)
    inc_plot.add_random(add_text = False)
    if output is None:
        inc_plot.show()
    else:
        inc_plot.show()
        inc_plot.save(output)
        inc_plot.close()

# %%
# datasets and models to access directories
data = ["ace", "ptsd", "nudging", "virus", "wilson", "software"]
models = ["Naïve Bayes", "Logistic Regression", "Random Forest", "Support Vector Machine"]
models = ["NB", "LR", "RF", "SVM"]
fe = ["TF-IDF", "D2V"]

# %%
# set time to compute how long plotting takes (some take over 4 hours!)
from datetime import datetime
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Starting Time =", current_time)
later = datetime.now()
currentlater = later.strftime("%H:%M:%S")
dif = (now-later)
# Out:
# this plot took 0:00:00.157144

# %%
# directory name where the simulations are stored
file = "one_seed"

# %%
# plot for every dataset * tfidfmodels 
for d in data:
    start = datetime.now()
    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/BCTD/" + d :  models[0]+ " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCTD/" + d : models[1] + " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCTD/" + d : models[2] + " + " + fe[0],
            "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCTD/" + d : models[3] + " + " + fe[0]
          }
    print("plotting " + d)
    print("\n")
    
    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/inclusion_tfidf_" + d + ".pdf"
    

    with Plot.from_paths(dic) as plot:
        inclusion_plot(plot, output= pname)
    
    end = datetime.now()
    print("this plot took", end-start)
# Out:
# plotting ace
# this plot took 0:16:41.872735
# plotting ptsd
# this plot took 0:51:04.572160
# plotting virus
# this plot took 0:21:40.998063
# plotting wilson
# this plot took 0:23:08.578606
# plotting software
# this plot took 1:46:18.250964

# %%
# plot for every dataset * tfidfmodels 
for d in data:
    start = datetime.now()
    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/BCTD/" + d :  models[0]+ " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCTD/" + d : models[1] + " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCTD/" + d : models[2] + " + " + fe[0],
            "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCTD/" + d : models[3] + " + " + fe[0]
          }
    print("plotting " + d)
    print("\n")
    
    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/nolegend_inclusion_tfidf_" + d + ".pdf"
    

    with Plot.from_paths(dic) as plot:
        inclusion_plot_nolegend(plot, output= pname)
    
    end = datetime.now()
    print("this plot took", end-start)

# %%
# plot for every dataset * d2vmodels 
for d in data:
    start = datetime.now()
    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCDD/" + d : models[1] + " + " + fe[1],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCDD/" + d : models[2] + " + " + fe[1],
            "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCDD/" + d : models[3] + " + " + fe[1]
          }
    
    print("plotting " + d)
    print("\n")

    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/inclusion_d2v_" + d + ".pdf"
    
    with Plot.from_paths(dic) as plot:
        inclusion_plot(plot, output= pname)
        
    end = datetime.now()
    print("this plot took", end-start)
    print("\n")
# Out:
# plotting ace
# this plot took 0:13:16.032031
#
#
# plotting ptsd
# this plot took 0:40:25.388106
#
#
# plotting virus
# this plot took 0:14:15.224183
#
#
# plotting wilson
# this plot took 0:14:34.421451
#
#
# plotting software
# this plot took 1:02:41.237854

# %%
# how d2v compare to their tf-idf counterparts


# Logistic Regression
for d in data:
    start = datetime.now()
    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCTD/" + d : models[1] + " + " + fe[0],
            "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCDD/" + d : models[1] + " + " + fe[1]
          }
    print("plotting " + d)
    print("\n")
    
    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/inclusion_d2v_vs_tfidf_logistic_" + d + ".pdf"
    
    with Plot.from_paths(dic) as plot:
          inclusion_plot(plot, output= pname)

    end = datetime.now()
    print("this plot took", end-start)
    print("\n")
              
# Random Forests
for d in data:
    start = datetime.now()
    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCTD/" + d : models[2] + " + " + fe[0],
            "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCDD/" + d : models[2] + " + " + fe[1]
          }
    print("plotting " + d)
    print("\n")
    
    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/inclusion_d2v_vs_tfidf_rf_" + d + ".pdf"
    
    with Plot.from_paths(dic) as plot:
        inclusion_plot(plot, output= pname)
    
    end = datetime.now()
    print("this plot took", end-start)
    print("\n")

# Support Vector Machine 
for d in data:
    start = datetime.now()
    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCTD/" + d : models[3] + " + " + fe[0],
            "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCDD/" + d : models[3] + " + " + fe[1]
          }
    print("plotting " + d)
    print("\n")
    
    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/inclusion_d2v_vs_tfidf_svm_" + d + ".pdf"
    
    with Plot.from_paths(dic) as plot:
        inclusion_plot(plot, output= pname)
    
    end = datetime.now()
    print("this plot took", end-start)
    print("\n")
# Out:
# plotting ace
# this plot took 0:06:23.073959
#
#
# plotting ptsd
# this plot took 0:18:07.263296
#
#
# plotting virus
# this plot took 0:06:41.573384
#
#
# plotting wilson
# this plot took 0:09:36.718607
#
#
# plotting software
# this plot took 0:37:03.405978
#
#
# plotting ace
# this plot took 0:07:29.940105
#
#
# plotting ptsd
# this plot took 0:24:38.585839
#
#
# plotting virus
# this plot took 0:10:29.872969
#
#
# plotting wilson
# this plot took 0:09:38.167579
#
#
# plotting software
# this plot took 0:51:06.147489
#
#
# plotting ace
# this plot took 0:09:04.508398
#
#
# plotting ptsd
# this plot took 0:23:45.964862
#
#
# plotting virus
# this plot took 0:08:39.080873
#
#
# plotting wilson
# this plot took 0:08:32.105714
#
#
# plotting software
# this plot took 0:44:45.516390

# %%
# compare all plots at once 
for d in data:
    start = datetime.now()

    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/BCTD/" + d :  models[0]+ " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCTD/" + d : models[1] + " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCTD/" + d : models[2] + " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCTD/" + d : models[3] + " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCDD/" + d : models[1] + " + " + fe[1],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCDD/" + d : models[2] + " + " + fe[1],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCDD/" + d : models[3] + " + " + fe[1]
          }
    print("plotting", d)
    print("\n")
    
    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/inclusion_all_" + d + ".pdf"
    
    with Plot.from_paths(dic) as plot:
        inclusion_plot(plot, output= pname)
    
    
    end = datetime.now()
    print("this plot took", end-start)
    print("\n")
# Out:
# plotting ace
# this plot took 0:46:53.265872
#
#
# plotting ptsd
# this plot took 1:36:19.812897
#
#
# plotting virus
# this plot took 0:34:36.125479
#
#
# plotting wilson
# this plot took 0:33:02.964419
#
#
# plotting software
# this plot took 2:55:47.215864

# %%
# compare all plots at once - without legend
for d in data:
    start = datetime.now()

    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/BCTD/" + d :  models[0]+ " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCTD/" + d : models[1] + " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCTD/" + d : models[2] + " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCTD/" + d : models[3] + " + " + fe[0],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCDD/" + d : models[1] + " + " + fe[1],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCDD/" + d : models[2] + " + " + fe[1],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCDD/" + d : models[3] + " + " + fe[1]
          }
    print("plotting", d)
    print("\n")
    
    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/nolegend_inclusion_all_" + d + ".pdf"
    
    with Plot.from_paths(dic) as plot:
        inclusion_plot_nolegend(plot, output= pname)
    
    
    end = datetime.now()
    print("this plot took", end-start)
    print("\n")

# %%
# plot for every dataset * d2vmodels 
for d in data:
    start = datetime.now()
    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCDD/" + d : models[1] + " + " + fe[1],
           "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCDD/" + d : models[2] + " + " + fe[1],
            "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCDD/" + d : models[3] + " + " + fe[1]
          }
    
    print("plotting " + d)
    print("\n")

    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/nolegend_inclusion_d2v_" + d + ".pdf"
    
    with Plot.from_paths(dic) as plot:
        inclusion_plot_nolegend(plot, output= pname)
        
    end = datetime.now()
    print("this plot took", end-start)
    print("\n")

# %%
# how d2v compare to their tf-idf counterparts

# Logistic Regression
for d in data:
    start = datetime.now()
    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCTD/" + d : models[1] + " + " + fe[0],
            "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/LCDD/" + d : models[1] + " + " + fe[1]
          }
    print("plotting " + d)
    print("\n")
    
    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/nolegend_inclusion_d2v_vs_tfidf_logistic_" + d + ".pdf"
    
    with Plot.from_paths(dic) as plot:
          inclusion_plot_nolegend(plot, output= pname)

    end = datetime.now()
    print("this plot took", end-start)
    print("\n")
              
# Random Forests
for d in data:
    start = datetime.now()
    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCTD/" + d : models[2] + " + " + fe[0],
            "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/RCDD/" + d : models[2] + " + " + fe[1]
          }
    print("plotting " + d)
    print("\n")
    
    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/nolegend_inclusion_d2v_vs_tfidf_rf_" + d + ".pdf"
    
    with Plot.from_paths(dic) as plot:
        inclusion_plot_nolegend(plot, output= pname)
    
    end = datetime.now()
    print("this plot took", end-start)
    print("\n")

# Support Vector Machine 
for d in data:
    start = datetime.now()
    dic = {"/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCTD/" + d : models[3] + " + " + fe[0],
            "/Volumes/Gerbrich/asreview/simoutput/" + file +  "/SCDD/" + d : models[3] + " + " + fe[1]
          }
    print("plotting " + d)
    print("\n")
    
    pname = "/Volumes/Gerbrich/asreview/results/" + file +  "/plots/" + d + "/nolegend_inclusion_d2v_vs_tfidf_svm_" + d + ".pdf"
    
    with Plot.from_paths(dic) as plot:
        inclusion_plot_nolegend(plot, output= pname)
    
    end = datetime.now()
    print("this plot took", end-start)
    print("\n")
